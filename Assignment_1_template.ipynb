# %% [markdown]
# ### Assignment 1 Deep Learning and Sensor fusion 2026
#
# Multi class Classification

# %% [markdown]
# ### Necessary iomport here

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.utils.data import Dataset
import torch.nn.functional as F
import matplotlib.pyplot as plt
from PIL import Image
from torchvision import transforms
import os 
import numpy as np 
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split 

print(f"[INFO] Torch infos: {torch.__version__}")

DATASET_PATH = os.path.join("BoneBreakClassification")
# Out:
# [INFO] Torch infos: 2.9.1+cu128

# %%
# some helpers
def load_data(dataset_path, class_names, type_of_data_to_load):
    # for each class name 
    images, labels = list(), list() 
    for el in class_names.keys():
        print(f"[WALKING] Walking into {el}")
        for images_name in os.listdir(os.path.join(dataset_path, el, type_of_data_to_load)):
            full_image_path = os.path.join(dataset_path, el, type_of_data_to_load, images_name)
            images.append(full_image_path)
            labels.append(class_names[el])
    return images, labels

# %% [markdown]
# # set Dataset path
# The path yopu see in the code point to my folder
#
# ```
# .
# ├── Assignment_1
# │   ├── Assignment_1_four_layers.ipynb
# │   ├── Assignment_1_template.ipynb
# │   ├── Assignment_1_three_layers.ipynb
# │   └── cnn_ass_1.pt
# ├── Dataset
# │   ├── BoneBreakClassification
#
# ```
#
# If you put the data in a different place change it.

# %%
DATASET_PATH = os.path.join("BoneBreakClassification")

# %% [markdown]
# ### (1) Load dataset

# %%
class_names = dict()   

temp = os.listdir(DATASET_PATH)
temp = sorted(temp)

# prep up list and class number together
for i in range(len(temp)):
    class_names[temp[i]] = i

data_to_split, labels_to_split = load_data(dataset_path=DATASET_PATH,
                                                       class_names=class_names,
                                                       type_of_data_to_load="Train")

print(f"[DATA TO SPLIT] Data loaded complete {len(data_to_split)} Labeles are {len(labels_to_split)}")

# load test data 
test_data_handler, test_labels_handler = load_data(dataset_path=DATASET_PATH,
                                                   class_names=class_names,
                                                   type_of_data_to_load="Test")

print(f"[TRAIN DATA LOADED] Data loaded complete {len(test_data_handler)} Labeles are {len(test_labels_handler)}")
# Out:
# [WALKING] Walking into Avulsion fracture
# [WALKING] Walking into Comminuted fracture
# [WALKING] Walking into Fracture Dislocation
# [WALKING] Walking into Greenstick fracture
# [WALKING] Walking into Hairline Fracture
# [WALKING] Walking into Impacted fracture
# [WALKING] Walking into Longitudinal fracture
# [WALKING] Walking into Oblique fracture
# [WALKING] Walking into Pathological fracture
# [WALKING] Walking into Spiral Fracture
# [DATA TO SPLIT] Data loaded complete 989 Labeles are 989
# [WALKING] Walking into Avulsion fracture
# [WALKING] Walking into Comminuted fracture
# [WALKING] Walking into Fracture Dislocation
# [WALKING] Walking into Greenstick fracture
# [WALKING] Walking into Hairline Fracture
# [WALKING] Walking into Impacted fracture
# [WALKING] Walking into Longitudinal fracture
# [WALKING] Walking into Oblique fracture
# [WALKING] Walking into Pathological fracture
# [WALKING] Walking into Spiral Fracture
# [TRAIN DATA LOADED] Data loaded complete 140 Labeles are 140

# %% [markdown]
# # (2) leave this cell because we need to create a val dataset and it is not there as default

# %%
# here you can split validation in stead of test so you can preserve intacted the test set. 
train_data_handler, validation_data_handler, train_labels_handler, validation_labels_handler = train_test_split(np.array(data_to_split), np.array(labels_to_split), test_size=0.20)

print(f"[TRAIN DATA] The train data is {train_data_handler.shape}  and its labels are {train_labels_handler.shape}")
print(f"[VALIDATION DATA] The validation data is {validation_data_handler.shape}  and its labels are {validation_labels_handler.shape}")

# my data loader need list yours? adapt it to your code
train_data_handler = list(train_data_handler)
train_labels_handler = list(train_labels_handler)

validation_data_handler = list(validation_data_handler)
validation_labels_handler = list(validation_labels_handler)
# Out:
# [TRAIN DATA] The train data is (791,)  and its labels are (791,)
# [VALIDATION DATA] The validation data is (198,)  and its labels are (198,)

# %% [markdown]
# ### (3) Here ate two transforms one for training and one for evaluation
#
# train transform need data augmentation:
# - add random flip
# - add random rotation
# - add color jitter
#
# both need need:
# - resize
# - toTensor handler
# - Normalize (use the provided MEAN and STD)
#
# Note that the evaluation transform does not need data augmentation.

# %%
TARGET_H = 224
TARGET_W = 224
IMAGE_MEAN = [0.485,0.456,0.406]
IMAGE_STD = [0.229,0.224,0.225]

rotation_degree = 20
# create transform 
train_transform = transforms.Compose([
    transforms.Resize((TARGET_W,TARGET_H)),
    transforms.RandomVerticalFlip(),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(rotation_degree),
    transforms.ColorJitter(),
    transforms.ToTensor(),
    transforms.Normalize(IMAGE_MEAN,IMAGE_STD)
])

evaluation_transform = transforms.Compose([
    transforms.Resize((TARGET_W,TARGET_H)),
    transforms.ToTensor(),
    transforms.Normalize(IMAGE_MEAN,IMAGE_STD)
])

# %%
class MyDataset(Dataset):
    def __init__(self, list_of_pathes, list_of_classes, transform=None) -> None:
        super().__init__()
        self.list_of_pathes = list_of_pathes
        self.list_of_classes = list_of_classes
        self.transform = transform

    def __len__(self):
        return len(self.list_of_pathes)
    
    def __getitem__(self, index):
        path = self.list_of_pathes[index]
        label = self.list_of_classes[index]
        image = Image.open(path).convert("RGB")
        image_as_tensor= self.transform(image)
        # return image and label
        return image_as_tensor, label

# %% [markdown]
# ### (4) Create data loder from the MyDataset class

# %%
train_dataset = MyDataset(list_of_pathes=train_data_handler,
                          list_of_classes=train_labels_handler,
                          transform=train_transform)

validation_dataset = MyDataset(list_of_pathes=validation_data_handler,
                                list_of_classes=validation_labels_handler,
                                transform=evaluation_transform)

test_dataset = MyDataset(list_of_pathes=test_data_handler,
                          list_of_classes=test_labels_handler,
                          transform=evaluation_transform)

# put those here
train_loader = DataLoader(train_dataset,batch_size=64,shuffle=True,num_workers= 0,pin_memory= True)
val_loader = DataLoader(validation_dataset,batch_size=128,shuffle=False, num_workers= 0,pin_memory= True)
test_loader = DataLoader(test_dataset,batch_size=128,shuffle=False, num_workers= 0,pin_memory= True)

# %% [markdown]
# ### Instance of the CNN
# Use the Sequential API it is faster
# - This cnn has two hidden layers (conv2d -> proper activation -> max pool 2d)  one has 16 untis and the second has 32 units
# - Add a flatten layer
# - Classifier need 128 Linear unit proper activation and set dropdown at 0.5
# - The last layer of the classifier how many units need?

# %%
class MyCNN(nn.Module):
    def __init__(self, 
                 number_of_output_classes, 
                 kernel_size, 
                 padding_size, 
                 pooling_size, 
                 input_channels,
                 dropout_probabilities: float,
                 dense_units: list[int],
                 layers_list: list[int]
                 ):
        
        super().__init__()

        layers = []

        input_units = input_channels

        for output_units in layers_list:
            layers +=[
                nn.Conv2d(input_units,output_units,kernel_size=kernel_size,padding=padding_size),
                nn.ReLU(inplace=True),
                nn.MaxPool2d(pooling_size)
            ]
            input_units = output_units
        
        self.features = nn.Sequential(*layers)

        mlp = []
        count_layer = 0
        for i in layers_list:
            count_layer +=1
        if count_layer == 2: 
            in_features = layers_list[-1]*56*56 # since maxpool 2 times
        else:
            in_features = layers_list[-1]*28*28 # since maxpool 3 times


        for h in dense_units:
            mlp += [
                nn.Linear(in_features,h),
                nn.ReLU(inplace=True),
                nn.Dropout(p=dropout_probabilities)
            ]
            in_features = h

        self.classifier = nn.Sequential(*mlp)
        self.flatten_layer = nn.Flatten()
        self.final_classifier = nn.Linear(in_features,number_of_output_classes)

    def forward(self,x):
        x = self.features(x)
        x = self.flatten_layer(x)
        x = self.classifier(x)
        x = self.final_classifier(x)

        return x

# %% [markdown]
# ### (5) Add proper optimizer and loss function set training epochs to 50

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print (f"Device is {device}")
# Out:
# Device is cuda

# %%
def train(model, loader, criterion, optimizer, device):
    model.train()
    running_loss = 0.0
    correct = 0 
    total = 0
    
    for images, labels in loader :
        images,labels = images.to(device), labels.to(device)
        
        optimizer.zero_grad()
        logits = model(images)
        loss = criterion(logits,labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()*images.size(0)
        preds = logits.argmax(dim=1)
        correct += (preds == labels).sum().item()
        total += labels.size(0)
        
    train_loss = running_loss / total
    accuracy = correct / total
    return train_loss, accuracy

params = {
    "number_of_output_classes":10, 
    "kernel_size":3, 
    "padding_size":1, 
    "pooling_size":2, 
    "input_channels":3,
    "dropout_probabilities":0.5,
    "dense_units":[128],
    "layers_list":[16,32] 
}
model = MyCNN(**params)
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr= 1e-3,weight_decay=1e-4)

# %%
@torch.no_grad()
def evaluation(model,loader,criterion,device):
    model.eval()
    correct,total = 0,0
    running_loss = 0.0
    
    for image, label in loader:
        image = image.to(device)
        label = label.to(device)
        
        logits = model(image)
        loss= criterion(logits,label)
        current__image_loss = loss.item()
        
        running_loss += current__image_loss*image.size(0)
        
        prediction = logits.argmax(dim=1)
        correct += (prediction == label).sum().item()
        total += label.size(0)
        
    val_loss = running_loss / total
    val_accuracy = correct / total
    return val_loss, val_accuracy

# %% [markdown]
# # (6) add here the train and evaluation loop collect loss and accuracy, we want to see curves here

# %%
epochs = 50
best_val_acc = 0
val_acc = 0
train_losses, train_accs = [], []
val_losses, val_accs = [], []

for epoch in range (1, epochs + 1):
    train_loss, train_acc = train(model = model,loader=train_loader, criterion=criterion, optimizer=optimizer, device=device)
    print(f"Epoch #{epoch}/{epochs}, Train Loss = {train_loss:.4f}, Accuracy = {train_acc:.3f}")  
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    val_loss, val_acc = evaluation(model = model,loader=val_loader, criterion=criterion, device=device)
    print(f"Epoch #{epoch}/{epochs}, Val Loss = {val_loss:.4f}, Val Accuracy = {val_acc:.3f}")  
    val_losses.append(val_loss)
    val_accs.append(val_acc)
    
    if (val_acc > best_val_acc):
        best_val_acc = val_acc
        torch.save(model.state_dict(),"Assignment1_best_model_2layer.pt")
print("Best Val Accuracy", best_val_acc)
# Out:
# Epoch #1/50, Train Loss = 4.2946, Accuracy = 0.115
# Epoch #1/50, Val Loss = 2.3082, Val Accuracy = 0.101
# Epoch #2/50, Train Loss = 2.2936, Accuracy = 0.140
# Epoch #2/50, Val Loss = 2.3026, Val Accuracy = 0.121
# Epoch #3/50, Train Loss = 2.2907, Accuracy = 0.149
# Epoch #3/50, Val Loss = 2.3008, Val Accuracy = 0.116
# Epoch #4/50, Train Loss = 2.2910, Accuracy = 0.131
# Epoch #4/50, Val Loss = 2.2993, Val Accuracy = 0.106
# Epoch #5/50, Train Loss = 2.2788, Accuracy = 0.152
# Epoch #5/50, Val Loss = 2.3001, Val Accuracy = 0.116
# Epoch #6/50, Train Loss = 2.2638, Accuracy = 0.148
# Epoch #6/50, Val Loss = 2.2944, Val Accuracy = 0.141
# Epoch #7/50, Train Loss = 2.2605, Accuracy = 0.142
# Epoch #7/50, Val Loss = 2.2889, Val Accuracy = 0.167
# Epoch #8/50, Train Loss = 2.2607, Accuracy = 0.154
# Epoch #8/50, Val Loss = 2.2783, Val Accuracy = 0.146
# Epoch #9/50, Train Loss = 2.2373, Accuracy = 0.152
# Epoch #9/50, Val Loss = 2.2939, Val Accuracy = 0.157
# Epoch #10/50, Train Loss = 2.2317, Accuracy = 0.173
# Epoch #10/50, Val Loss = 2.2657, Val Accuracy = 0.167
# Epoch #11/50, Train Loss = 2.2413, Accuracy = 0.166
# Epoch #11/50, Val Loss = 2.2711, Val Accuracy = 0.162
# Epoch #12/50, Train Loss = 2.2270, Accuracy = 0.166
# Epoch #12/50, Val Loss = 2.2650, Val Accuracy = 0.167
# Epoch #13/50, Train Loss = 2.2044, Accuracy = 0.178
# Epoch #13/50, Val Loss = 2.2459, Val Accuracy = 0.197
# Epoch #14/50, Train Loss = 2.2132, Accuracy = 0.168
# Epoch #14/50, Val Loss = 2.2459, Val Accuracy = 0.202
# Epoch #15/50, Train Loss = 2.1958, Accuracy = 0.196
# Epoch #15/50, Val Loss = 2.2763, Val Accuracy = 0.146
# Epoch #16/50, Train Loss = 2.1986, Accuracy = 0.186
# Epoch #16/50, Val Loss = 2.2626, Val Accuracy = 0.202
# Epoch #17/50, Train Loss = 2.1973, Accuracy = 0.187
# Epoch #17/50, Val Loss = 2.2629, Val Accuracy = 0.187
# Epoch #18/50, Train Loss = 2.1824, Accuracy = 0.200
# Epoch #18/50, Val Loss = 2.2567, Val Accuracy = 0.182
# Epoch #19/50, Train Loss = 2.1589, Accuracy = 0.195
# Epoch #19/50, Val Loss = 2.2489, Val Accuracy = 0.222
# Epoch #20/50, Train Loss = 2.1824, Accuracy = 0.187
# Epoch #20/50, Val Loss = 2.2668, Val Accuracy = 0.192
# Epoch #21/50, Train Loss = 2.1597, Accuracy = 0.205
# Epoch #21/50, Val Loss = 2.2601, Val Accuracy = 0.192
# Epoch #22/50, Train Loss = 2.1402, Accuracy = 0.202
# Epoch #22/50, Val Loss = 2.2566, Val Accuracy = 0.192
# Epoch #23/50, Train Loss = 2.1500, Accuracy = 0.206
# Epoch #23/50, Val Loss = 2.2385, Val Accuracy = 0.217
# Epoch #24/50, Train Loss = 2.1205, Accuracy = 0.238
# Epoch #24/50, Val Loss = 2.2510, Val Accuracy = 0.227
# Epoch #25/50, Train Loss = 2.1656, Accuracy = 0.176
# Epoch #25/50, Val Loss = 2.2408, Val Accuracy = 0.187
# Epoch #26/50, Train Loss = 2.1382, Accuracy = 0.215
# Epoch #26/50, Val Loss = 2.2375, Val Accuracy = 0.192
# Epoch #27/50, Train Loss = 2.1377, Accuracy = 0.214
# Epoch #27/50, Val Loss = 2.2344, Val Accuracy = 0.212
# Epoch #28/50, Train Loss = 2.1161, Accuracy = 0.209
# Epoch #28/50, Val Loss = 2.2173, Val Accuracy = 0.207
# Epoch #29/50, Train Loss = 2.0820, Accuracy = 0.231
# Epoch #29/50, Val Loss = 2.2471, Val Accuracy = 0.187
# Epoch #30/50, Train Loss = 2.1270, Accuracy = 0.216
# Epoch #30/50, Val Loss = 2.2467, Val Accuracy = 0.222
# Epoch #31/50, Train Loss = 2.0836, Accuracy = 0.226
# Epoch #31/50, Val Loss = 2.2821, Val Accuracy = 0.192
# Epoch #32/50, Train Loss = 2.0886, Accuracy = 0.220
# Epoch #32/50, Val Loss = 2.2396, Val Accuracy = 0.227
# Epoch #33/50, Train Loss = 2.0707, Accuracy = 0.241
# Epoch #33/50, Val Loss = 2.2578, Val Accuracy = 0.207
# Epoch #34/50, Train Loss = 2.0606, Accuracy = 0.241
# Epoch #34/50, Val Loss = 2.2546, Val Accuracy = 0.207
# Epoch #35/50, Train Loss = 2.0588, Accuracy = 0.253
# Epoch #35/50, Val Loss = 2.2315, Val Accuracy = 0.212
# Epoch #36/50, Train Loss = 2.0478, Accuracy = 0.250
# Epoch #36/50, Val Loss = 2.2483, Val Accuracy = 0.197
# Epoch #37/50, Train Loss = 2.0409, Accuracy = 0.243
# Epoch #37/50, Val Loss = 2.2316, Val Accuracy = 0.222
# Epoch #38/50, Train Loss = 2.0336, Accuracy = 0.268
# Epoch #38/50, Val Loss = 2.2519, Val Accuracy = 0.232
# Epoch #39/50, Train Loss = 2.0042, Accuracy = 0.272
# Epoch #39/50, Val Loss = 2.2616, Val Accuracy = 0.227
# Epoch #40/50, Train Loss = 1.9910, Accuracy = 0.274
# Epoch #40/50, Val Loss = 2.2833, Val Accuracy = 0.217
# Epoch #41/50, Train Loss = 1.9968, Accuracy = 0.258
# Epoch #41/50, Val Loss = 2.2735, Val Accuracy = 0.162
# Epoch #42/50, Train Loss = 2.0148, Accuracy = 0.265
# Epoch #42/50, Val Loss = 2.2603, Val Accuracy = 0.187
# Epoch #43/50, Train Loss = 1.9717, Accuracy = 0.281
# Epoch #43/50, Val Loss = 2.2611, Val Accuracy = 0.207
# Epoch #44/50, Train Loss = 1.9818, Accuracy = 0.290
# Epoch #44/50, Val Loss = 2.2521, Val Accuracy = 0.207
# Epoch #45/50, Train Loss = 1.9674, Accuracy = 0.278
# Epoch #45/50, Val Loss = 2.2512, Val Accuracy = 0.212
# Epoch #46/50, Train Loss = 1.9471, Accuracy = 0.301
# Epoch #46/50, Val Loss = 2.3010, Val Accuracy = 0.207
# Epoch #47/50, Train Loss = 1.9414, Accuracy = 0.300
# Epoch #47/50, Val Loss = 2.2533, Val Accuracy = 0.217
# Epoch #48/50, Train Loss = 1.9174, Accuracy = 0.284
# Epoch #48/50, Val Loss = 2.3111, Val Accuracy = 0.237
# Epoch #49/50, Train Loss = 1.9398, Accuracy = 0.288
# Epoch #49/50, Val Loss = 2.2473, Val Accuracy = 0.232
# Epoch #50/50, Train Loss = 1.9263, Accuracy = 0.295
# Epoch #50/50, Val Loss = 2.2672, Val Accuracy = 0.237
# Best Val Accuracy 0.23737373737373738

# %%
model.load_state_dict(torch.load("Assignment1_best_model_2layer.pt"))
print(f"Loaded best model with validation accuracy: {best_val_acc:.4f}")
# Out:
# Loaded best model with validation accuracy: 0.2374

# %%
plt.figure(figsize=(12, 5))
# Plot 1: Loss Curves
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='red', linestyle='--')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
# Plot 2: Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accs) + 1), train_accs, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_accs) + 1), val_accs, label='Validation Accuracy', color='red', linestyle='--')
plt.title('Accuracy vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # (7) Make prediction and shows some predicted images

# %%
def visualize_predictions(model, data_loader, device, num_images=8, figsize=(15, 10)):

    model.eval()
    images, labels = next(iter(data_loader))
    images, labels = images.to(device), labels.to(device)
    
    with torch.no_grad():
        logits = model(images)
        probs = F.softmax(logits, dim=1)  
        predictions = torch.argmax(probs, dim=1)
    
    plt.figure(figsize=figsize)
    for i in range(num_images):
        plt.subplot(2, 4, i + 1)
        img = images[i].cpu().numpy().transpose((1, 2, 0))
        img = img * IMAGE_STD + IMAGE_MEAN  
        img = np.clip(img, 0, 1) 
        plt.imshow(img)
        
        gt = labels[i].item()
        pred = predictions[i].item()
        p_val = probs[i][pred].item()
        
        plt.title(f"GT:{gt} Pred:{pred}\nP:{p_val:.2f}")
        plt.axis('off')
    
    plt.tight_layout()
    plt.show()

# %%
visualize_predictions(model, test_loader, device)

# %% [markdown]
# # (8) Make Evaluation with confusion matrix

# %%
def plot_confusion_matrix(model, data_loader, device, title, figsize=(10, 8)):
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for images, labels in data_loader:
            images, labels = images.to(device), labels.to(device)
            logits = model(images)
            predictions = torch.argmax(logits, dim=1)
            all_preds.extend(predictions.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    all_preds = np.array(all_preds)
    all_labels = np.array(all_labels)
    
    cm = confusion_matrix(all_labels, all_preds)
    
    plt.figure(figsize=figsize)
    plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
    plt.title(title)
    plt.colorbar()

    num_classes = len(np.unique(all_labels))
    tick_marks = np.arange(num_classes)
    
    if class_names is not None:
        plt.xticks(tick_marks, class_names, rotation=45, ha='right')
        plt.yticks(tick_marks, class_names)
    else:
        plt.xticks(tick_marks, range(num_classes))
        plt.yticks(tick_marks, range(num_classes))
    
    thresh = cm.max() / 2.
    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            plt.text(j, i, format(cm[i, j], 'd'),
                    ha="center", va="center",
                    color="white" if cm[i, j] > thresh else "black")
    
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.show()

    accuracy = np.sum(all_preds == all_labels) / len(all_labels)
    print(f"Test Accuracy: {accuracy:.4f} ({accuracy*100:.2f}%)")
    
    return accuracy, cm

# %%
# For first model (2 layers)
accuracy, cm = plot_confusion_matrix(
    model, 
    test_loader, 
    device, 
    title='Confusion Matrix - 2 Layer Model'
)
# Out:
# Test Accuracy: 0.1357 (13.57%)

# %% [markdown]
# ### Instance of a new CNN
# Use the Sequential API it is faster
# - This cnn has tre hidden layers (conv2d -> proper activation -> max pool 2d)  one has 16 untis, the second has 32 units, and the third has 64
# - Add a flatten layer
# - Classifier need 128 Linear unit proper activation and set dropdown at 0.5
# - The last layer of the classifier how many units need?
#
# Repeat from 5 to 8

# %% [markdown]
# Just taking the same code and changing the layers and running them to see the difference.

# %%
params = {
    "number_of_output_classes":10, 
    "kernel_size":3, 
    "padding_size":1, 
    "pooling_size":2, 
    "input_channels":3,
    "dropout_probabilities":0.5,
    "dense_units":[128],
    "layers_list":[16,32,64] 
}
model = MyCNN(**params)
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr= 1e-3,weight_decay=1e-4)

# %%
epochs = 50
best_val_acc = 0
val_acc = 0
train_losses, train_accs = [], []
val_losses, val_accs = [], []

for epoch in range (1, epochs + 1):
    train_loss, train_acc = train(model = model,loader=train_loader, criterion=criterion, optimizer=optimizer, device=device)
    print(f"Epoch #{epoch}/{epochs}, Train Loss = {train_loss:.4f}, Accuracy = {train_acc:.3f}")  
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    val_loss, val_acc = evaluation(model = model,loader=val_loader, criterion=criterion, device=device)
    print(f"Epoch #{epoch}/{epochs}, Val Loss = {val_loss:.4f}, Val Accuracy = {val_acc:.3f}")  
    val_losses.append(val_loss)
    val_accs.append(val_acc)
    
    if (val_acc > best_val_acc):
        best_val_acc = val_acc
        torch.save(model.state_dict(),"Assignment1_best_model_3layer.pt")
print("Best Val Accuracy", best_val_acc)
# Out:
# Epoch #1/50, Train Loss = 2.4275, Accuracy = 0.126
# Epoch #1/50, Val Loss = 2.3019, Val Accuracy = 0.121
# Epoch #2/50, Train Loss = 2.2786, Accuracy = 0.131
# Epoch #2/50, Val Loss = 2.2933, Val Accuracy = 0.121
# Epoch #3/50, Train Loss = 2.2587, Accuracy = 0.143
# Epoch #3/50, Val Loss = 2.2811, Val Accuracy = 0.146
# Epoch #4/50, Train Loss = 2.2690, Accuracy = 0.131
# Epoch #4/50, Val Loss = 2.2778, Val Accuracy = 0.141
# Epoch #5/50, Train Loss = 2.2449, Accuracy = 0.161
# Epoch #5/50, Val Loss = 2.2752, Val Accuracy = 0.157
# Epoch #6/50, Train Loss = 2.2354, Accuracy = 0.155
# Epoch #6/50, Val Loss = 2.2687, Val Accuracy = 0.172
# Epoch #7/50, Train Loss = 2.2301, Accuracy = 0.166
# Epoch #7/50, Val Loss = 2.3104, Val Accuracy = 0.162
# Epoch #8/50, Train Loss = 2.2240, Accuracy = 0.181
# Epoch #8/50, Val Loss = 2.2649, Val Accuracy = 0.162
# Epoch #9/50, Train Loss = 2.2292, Accuracy = 0.180
# Epoch #9/50, Val Loss = 2.2640, Val Accuracy = 0.177
# Epoch #10/50, Train Loss = 2.2035, Accuracy = 0.197
# Epoch #10/50, Val Loss = 2.2752, Val Accuracy = 0.182
# Epoch #11/50, Train Loss = 2.1876, Accuracy = 0.181
# Epoch #11/50, Val Loss = 2.2585, Val Accuracy = 0.207
# Epoch #12/50, Train Loss = 2.1825, Accuracy = 0.191
# Epoch #12/50, Val Loss = 2.2458, Val Accuracy = 0.197
# Epoch #13/50, Train Loss = 2.1702, Accuracy = 0.182
# Epoch #13/50, Val Loss = 2.2455, Val Accuracy = 0.187
# Epoch #14/50, Train Loss = 2.1379, Accuracy = 0.196
# Epoch #14/50, Val Loss = 2.2493, Val Accuracy = 0.182
# Epoch #15/50, Train Loss = 2.1597, Accuracy = 0.204
# Epoch #15/50, Val Loss = 2.2733, Val Accuracy = 0.202
# Epoch #16/50, Train Loss = 2.1439, Accuracy = 0.202
# Epoch #16/50, Val Loss = 2.2621, Val Accuracy = 0.167
# Epoch #17/50, Train Loss = 2.1383, Accuracy = 0.197
# Epoch #17/50, Val Loss = 2.2463, Val Accuracy = 0.222
# Epoch #18/50, Train Loss = 2.1203, Accuracy = 0.228
# Epoch #18/50, Val Loss = 2.2365, Val Accuracy = 0.187
# Epoch #19/50, Train Loss = 2.1063, Accuracy = 0.207
# Epoch #19/50, Val Loss = 2.2541, Val Accuracy = 0.187
# Epoch #20/50, Train Loss = 2.0898, Accuracy = 0.240
# Epoch #20/50, Val Loss = 2.2457, Val Accuracy = 0.207
# Epoch #21/50, Train Loss = 2.1194, Accuracy = 0.214
# Epoch #21/50, Val Loss = 2.2475, Val Accuracy = 0.222
# Epoch #22/50, Train Loss = 2.0867, Accuracy = 0.238
# Epoch #22/50, Val Loss = 2.2573, Val Accuracy = 0.187
# Epoch #23/50, Train Loss = 2.0818, Accuracy = 0.233
# Epoch #23/50, Val Loss = 2.2564, Val Accuracy = 0.212
# Epoch #24/50, Train Loss = 2.0523, Accuracy = 0.250
# Epoch #24/50, Val Loss = 2.2736, Val Accuracy = 0.217
# Epoch #25/50, Train Loss = 2.1085, Accuracy = 0.217
# Epoch #25/50, Val Loss = 2.2121, Val Accuracy = 0.212
# Epoch #26/50, Train Loss = 2.0463, Accuracy = 0.262
# Epoch #26/50, Val Loss = 2.2571, Val Accuracy = 0.217
# Epoch #27/50, Train Loss = 2.0321, Accuracy = 0.244
# Epoch #27/50, Val Loss = 2.2115, Val Accuracy = 0.253
# Epoch #28/50, Train Loss = 2.0384, Accuracy = 0.255
# Epoch #28/50, Val Loss = 2.2181, Val Accuracy = 0.237
# Epoch #29/50, Train Loss = 2.0294, Accuracy = 0.264
# Epoch #29/50, Val Loss = 2.2437, Val Accuracy = 0.237
# Epoch #30/50, Train Loss = 2.0228, Accuracy = 0.271
# Epoch #30/50, Val Loss = 2.2391, Val Accuracy = 0.232
# Epoch #31/50, Train Loss = 2.0384, Accuracy = 0.259
# Epoch #31/50, Val Loss = 2.2268, Val Accuracy = 0.237
# Epoch #32/50, Train Loss = 1.9748, Accuracy = 0.283
# Epoch #32/50, Val Loss = 2.2621, Val Accuracy = 0.247
# Epoch #33/50, Train Loss = 1.9988, Accuracy = 0.288
# Epoch #33/50, Val Loss = 2.2647, Val Accuracy = 0.247
# Epoch #34/50, Train Loss = 1.9821, Accuracy = 0.273
# Epoch #34/50, Val Loss = 2.2100, Val Accuracy = 0.242
# Epoch #35/50, Train Loss = 1.9496, Accuracy = 0.292
# Epoch #35/50, Val Loss = 2.2241, Val Accuracy = 0.258
# Epoch #36/50, Train Loss = 1.9706, Accuracy = 0.282
# Epoch #36/50, Val Loss = 2.1984, Val Accuracy = 0.242
# Epoch #37/50, Train Loss = 1.9027, Accuracy = 0.325
# Epoch #37/50, Val Loss = 2.2709, Val Accuracy = 0.242
# Epoch #38/50, Train Loss = 1.9103, Accuracy = 0.288
# Epoch #38/50, Val Loss = 2.2362, Val Accuracy = 0.232
# Epoch #39/50, Train Loss = 1.9114, Accuracy = 0.319
# Epoch #39/50, Val Loss = 2.2130, Val Accuracy = 0.227
# Epoch #40/50, Train Loss = 1.9228, Accuracy = 0.310
# Epoch #40/50, Val Loss = 2.2315, Val Accuracy = 0.227
# Epoch #41/50, Train Loss = 1.8925, Accuracy = 0.310
# Epoch #41/50, Val Loss = 2.2286, Val Accuracy = 0.253
# Epoch #42/50, Train Loss = 1.8998, Accuracy = 0.331
# Epoch #42/50, Val Loss = 2.2159, Val Accuracy = 0.258
# Epoch #43/50, Train Loss = 1.9010, Accuracy = 0.353
# Epoch #43/50, Val Loss = 2.2232, Val Accuracy = 0.263
# Epoch #44/50, Train Loss = 1.8710, Accuracy = 0.327
# Epoch #44/50, Val Loss = 2.1771, Val Accuracy = 0.273
# Epoch #45/50, Train Loss = 1.8127, Accuracy = 0.346
# Epoch #45/50, Val Loss = 2.1982, Val Accuracy = 0.258
# Epoch #46/50, Train Loss = 1.7871, Accuracy = 0.372
# Epoch #46/50, Val Loss = 2.2750, Val Accuracy = 0.247
# Epoch #47/50, Train Loss = 1.8174, Accuracy = 0.360
# Epoch #47/50, Val Loss = 2.2449, Val Accuracy = 0.263
# Epoch #48/50, Train Loss = 1.8086, Accuracy = 0.349
# Epoch #48/50, Val Loss = 2.2252, Val Accuracy = 0.268
# Epoch #49/50, Train Loss = 1.8116, Accuracy = 0.334
# Epoch #49/50, Val Loss = 2.2777, Val Accuracy = 0.258
# Epoch #50/50, Train Loss = 1.7446, Accuracy = 0.378
# Epoch #50/50, Val Loss = 2.3290, Val Accuracy = 0.253
# Best Val Accuracy 0.2727272727272727

# %%
model.load_state_dict(torch.load("Assignment1_best_model_3layer.pt"))
print(f"Loaded best model with validation accuracy: {best_val_acc:.4f}")
# Out:
# Loaded best model with validation accuracy: 0.2727

# %%
# Create a figure with two subplots side-by-side
plt.figure(figsize=(12, 5))

# Plot 1: Loss Curves
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='red', linestyle='--')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot 2: Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accs) + 1), train_accs, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_accs) + 1), val_accs, label='Validation Accuracy', color='red', linestyle='--')
plt.title('Accuracy vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
visualize_predictions(model, test_loader, device)

# %%
# For second model (3 layers)
accuracy, cm = plot_confusion_matrix(
    model, 
    test_loader, 
    device, 
    title='Confusion Matrix - 3 Layer Model'
)
# Out:
# Test Accuracy: 0.2071 (20.71%)

# %% [markdown]
# I wanted to play around with the model a bot more. here is that section

# %%
params = {
    "number_of_output_classes":10, 
    "kernel_size":3, 
    "padding_size":1, 
    "pooling_size":2, 
    "input_channels":3,
    "dropout_probabilities":0.1,
    "dense_units":[512],
    "layers_list":[16,32,64] 
}
model = MyCNN(**params)
model.to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(),lr= 1e-3,weight_decay=1e-4)

# %%
epochs = 50
best_val_acc = 0
val_acc = 0
train_losses, train_accs = [], []
val_losses, val_accs = [], []

for epoch in range (1, epochs + 1):
    train_loss, train_acc = train(model = model,loader=train_loader, criterion=criterion, optimizer=optimizer, device=device)
    print(f"Epoch #{epoch}/{epochs}, Train Loss = {train_loss:.4f}, Accuracy = {train_acc:.3f}")  
    train_losses.append(train_loss)
    train_accs.append(train_acc)

    val_loss, val_acc = evaluation(model = model,loader=val_loader, criterion=criterion, device=device)
    print(f"Epoch #{epoch}/{epochs}, Val Loss = {val_loss:.4f}, Val Accuracy = {val_acc:.3f}")  
    val_losses.append(val_loss)
    val_accs.append(val_acc)
    
    if (val_acc > best_val_acc):
        best_val_acc = val_acc
        torch.save(model.state_dict(),"Assignment1_best_model_3layer.pt")
print("Best Val Accuracy", best_val_acc)
# Out:
# Epoch #1/50, Train Loss = 2.6507, Accuracy = 0.109
# Epoch #1/50, Val Loss = 2.3009, Val Accuracy = 0.121
# Epoch #2/50, Train Loss = 2.2893, Accuracy = 0.137
# Epoch #2/50, Val Loss = 2.3028, Val Accuracy = 0.146
# Epoch #3/50, Train Loss = 2.2718, Accuracy = 0.134
# Epoch #3/50, Val Loss = 2.2896, Val Accuracy = 0.152
# Epoch #4/50, Train Loss = 2.2648, Accuracy = 0.157
# Epoch #4/50, Val Loss = 2.3106, Val Accuracy = 0.146
# Epoch #5/50, Train Loss = 2.2474, Accuracy = 0.158
# Epoch #5/50, Val Loss = 2.2795, Val Accuracy = 0.152
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[29], line 8
#       5 val_losses, val_accs = [], []
#       7 for epoch in range (1, epochs + 1):
# ----> 8     train_loss, train_acc = train(model = model,loader=train_loader, criterion=criterion, optimizer=optimizer, device=device)
#       9     print(f"Epoch #{epoch}/{epochs}, Train Loss = {train_loss:.4f}, Accuracy = {train_acc:.3f}")
#      10     train_losses.append(train_loss)
#
# Cell In[11], line 16, in train(model, loader, criterion, optimizer, device)
#      13 loss.backward()
#      14 optimizer.step()
# ---> 16 running_loss += loss.item()*images.size(0)
#      17 preds = logits.argmax(dim=1)
#      18 correct += (preds == labels).sum().item()
#
# KeyboardInterrupt:

# %%
model.load_state_dict(torch.load("Assignment1_best_model_3layer.pt"))
print(f"Loaded best model with validation accuracy: {best_val_acc:.4f}")

# %%
# Create a figure with two subplots side-by-side
plt.figure(figsize=(12, 5))

# Plot 1: Loss Curves
plt.subplot(1, 2, 1)
plt.plot(range(1, len(train_losses) + 1), train_losses, label='Training Loss', color='blue')
plt.plot(range(1, len(val_losses) + 1), val_losses, label='Validation Loss', color='red', linestyle='--')
plt.title('Loss vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Plot 2: Accuracy Curves
plt.subplot(1, 2, 2)
plt.plot(range(1, len(train_accs) + 1), train_accs, label='Training Accuracy', color='blue')
plt.plot(range(1, len(val_accs) + 1), val_accs, label='Validation Accuracy', color='red', linestyle='--')
plt.title('Accuracy vs. Epochs')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
visualize_predictions(model, test_loader, device)

# %%
accuracy, cm = plot_confusion_matrix(
    model, 
    test_loader, 
    device, 
    title='Confusion Matrix - 3 Layer Model'
)
